# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('diabetes (2).csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.SkinThickness.value_counts()
# Out:
# 0     227
# 32     31
# 30     27
# 27     23
# 23     22
# 33     20
# 18     20
# 28     20
# 31     19
# 39     18
# 19     18
# 29     17
# 37     16
# 26     16
# 22     16
# 40     16
# 25     16
# 35     15
# 41     15
# 36     14
# 15     14
# 17     14
# 20     13
# 24     12
# 42     11
# 13     11
# 21     10
# 34      8
# 46      8
# 38      7
# 12      7
# 14      6
# 16      6
# 11      6
# 43      6
# 45      6
# 10      5
# 44      5
# 48      4
# 47      4
# 50      3
# 49      3
# 54      2
# 52      2
# 7       2
# 8       2
# 60      1
# 56      1
# 63      1
# 51      1
# 99      1
# Name: SkinThickness, dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
def replace_zeros(column_name):
    mean = round(df[df[column_name]!= 0][column_name].mean(),0)
    df[column_name] = df[column_name].replace(0,mean)

# %%
for x in list(df)[1:-2]:
    print(x)
# Out:
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI
# DiabetesPedigreeFunction

# %%
df_new = pd.read_csv('new_diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_new.drop(['Unnamed: 0'],1,inplace=True)

# %%
df_new.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000      768.00000  768.000000
# mean      4.473958  121.451823      72.404948       29.24349  159.154948
# std       3.348798   30.807562      12.706550       10.63275  118.160425
# min       1.000000   44.000000      24.000000        7.00000    0.000000
# 25%       2.000000   99.000000      64.000000       21.00000   78.000000
# 50%       3.000000  116.000000      74.000000       30.00000  130.000000
# 75%       7.000000  141.000000      80.000000       36.25000  196.000000
# max      17.000000  199.000000     122.000000       99.00000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.497656                  0.471876   33.324219    0.348958
# std      6.954240                  0.331329   11.951023    0.476951
# ...

# %%
df_new['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
from sklearn.feature_selection import RFE, SelectKBest, chi2, f_classif,SelectFromModel
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score
from sklearn.model_selection import cross_val_score, cross_val_predict, GridSearchCV, train_test_split as tts
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
X = df_new.drop(['Outcome'],1)
y = df_new['Outcome']

# %%
X = pd.DataFrame(scalar.fit_transform(X),columns=list(X))

# %%
X.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.455995  0.862304      -0.031890       0.541747 -1.347817  0.158617
# 1    -1.038051 -1.183981      -0.504395       0.541747 -1.347817 -0.848619
# 2     1.053614  1.999129      -0.661897       0.541747 -1.347817 -1.323459
# 3    -1.038051 -1.054058      -0.504395      -0.587577 -0.551770 -0.632783
# 4    -1.038051  0.505016      -2.551917       0.541747  0.074905  1.525581
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  1.396253
# 1                 -0.365061 -0.194605
# 2                  0.604397 -0.110876
# 3                 -0.920763 -1.031899
# 4                  5.484909 -1.031899

# %% [markdown]
# # Model 1  Normal Logistic Regression

# %%
log_reg = LogisticRegression()
X_train, X_test, y_train, y_test = tts(X, y, test_size = 0.3, random_state = 42)
log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)
print(f'Accuracy Score : {accuracy_score(y_test, y_pred)}')
print(f'Confusion Matrix : {confusion_matrix(y_test, y_pred)}')
print(f'Classification Report: {classification_report(y_test, y_pred)}')
# Out:
# Accuracy Score : 0.7445887445887446
# Confusion Matrix : [[124  27]
#  [ 32  48]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81       151
#            1       0.64      0.60      0.62        80
#
#     accuracy                           0.74       231
#    macro avg       0.72      0.71      0.71       231
# weighted avg       0.74      0.74      0.74       231
# C:\Users\Ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# # Model 2 RFE

# %%
ranking = log_reg.coef_.tolist()[0]

# %%
features = list(X)

# %%
d = dict(zip(features,ranking))

# %%
d= pd.DataFrame(d.items(), columns=["Features", "Ranking"])

# %%
d
# Out:
#                    Features   Ranking
# 0               Pregnancies  0.140273
# 1                   Glucose  1.117285
# 2             BloodPressure -0.170108
# 3             SkinThickness -0.043997
# 4                   Insulin  0.022983
# 5                       BMI  0.786709
# 6  DiabetesPedigreeFunction  0.105771
# 7                       Age  0.468746

# %%
d.sort_values(["Ranking"], ascending = False)
# Out:
#                    Features   Ranking
# 1                   Glucose  1.117285
# 5                       BMI  0.786709
# 7                       Age  0.468746
# 0               Pregnancies  0.140273
# 6  DiabetesPedigreeFunction  0.105771
# 4                   Insulin  0.022983
# 3             SkinThickness -0.043997
# 2             BloodPressure -0.170108

# %%
f1 = ["Glucose", "BMI", "Age"]

# %%
rfe = RFE(log_reg, 4)

# %%
rfe.fit(X,y)
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
rfe.support_
# Out:
# array([ True,  True, False, False, False,  True,  True, False])

# %%
rfe.ranking_
# Out:
# array([1, 1, 3, 5, 4, 1, 1, 2])

# %%
features
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
f2 = ['Pregnancies','Glucose','BMI','DiabetesPedigreeFunction']

# %% [markdown]
# # Model 3 : Backward Elimination

# %%
def backward_elimination(Y,X):
    cols = list(X.columns)
    while len(cols) > 0:
        p = []
        X_new = X[cols]
        X_new = sm.add_constant(X_new)
        model = sm.OLS(Y, X_new).fit()
        pvalues = pd.Series(model.pvalues.values[1:],index = cols)
        max_pvalues = max(pvalues)
        feature_with_max_pvalues = pvalues.idxmax()
        if max_pvalues > 0.05:
            cols.remove(feature_with_max_pvalues)
        else:
            return cols
            break

# %%
_X = df_new.drop(['Outcome'],1)
_y = df_new['Outcome']
_X = pd.DataFrame(scalar.fit_transform(X),columns=list(X))

# %%
feature_selected = backward_elimination(_y,_X)
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
feature_selected
# Out:
# ['Pregnancies', 'Glucose', 'BMI', 'DiabetesPedigreeFunction', 'Age']

# %% [markdown]
# # Model 4 : Kbest

# %% [markdown]
# #### Using Chi2

# %%
from sklearn.preprocessing import MinMaxScaler
Minmax = MinMaxScaler()
_X_b = df.drop('Outcome',1)
_y_b = df['Outcome']
#Standardscaler will not work because Kbest does not take -ve value
_X_b = pd.DataFrame(Minmax.fit_transform(_X_b), columns=list(_X_b))

# %%
_X_b.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction       Age
# 0                  0.234415  0.483333
# 1                  0.116567  0.166667
# 2                  0.253629  0.183333
# 3                  0.038002  0.000000
# 4                  0.943638  0.200000

# %%
_y_b.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
features = list(_X_b)
features
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
kbest = SelectKBest(chi2, k = 4)

# %%
fit = kbest.fit(_X_b,_y_b)

# %%
fit.pvalues_
# Out:
# array([0.01042974, 0.00773032, 0.70403691, 0.46390984, 0.10879832,
#        0.16777946, 0.09673383, 0.00417592])

# %%
rankings = fit.scores_.tolist()

# %%
rankings
# Out:
# [6.559981802110764,
#  7.094909751980554,
#  0.14430633783049784,
#  0.536444846831558,
#  2.5715901571182176,
#  1.9026727769156078,
#  2.7585839144540985,
#  8.20569066697144]

# %%
d = pd.DataFrame(dict(zip(features,rankings)).items(), columns={"Features","Ranking"})

# %%
d.sort_values(['Ranking'], ascending=False)
# Out:
#                    Features   Ranking
# 7                       Age  8.205691
# 1                   Glucose  7.094910
# 0               Pregnancies  6.559982
# 6  DiabetesPedigreeFunction  2.758584
# 4                   Insulin  2.571590
# 5                       BMI  1.902673
# 3             SkinThickness  0.536445
# 2             BloodPressure  0.144306

# %%
feature_4 = ['Glucose', 'Age', 'Pregnancies', 'DiabetesPedigreeFunction']

# %% [markdown]
# #### f_classif

# %%
kbest = SelectKBest(f_classif, k = 4)
fit = kbest.fit(X,y)
print(fit.pvalues_)
rankings = fit.scores_.tolist()
d = pd.DataFrame(dict(zip(features,rankings)).items(), columns={"Features","Ranking"})
d.sort_values(['Ranking'], ascending=False)
# Out:
# [6.68142273e-10 4.04408491e-48 1.07604723e-04 3.73936831e-06
#  2.56095195e-05 8.69654854e-19 1.25460701e-06 7.35886163e-12]
#                    Features     Ranking
# 1                   Glucose  244.992929
# 5                       BMI   82.536787
# 7                       Age   48.429255
# 0               Pregnancies   39.101595
# 6  DiabetesPedigreeFunction   23.871300
# 3             SkinThickness   21.709909
# 4                   Insulin   17.937047
# 2             BloodPressure   15.156127

# %%
features_5 = ['Glucose', 'BMI', "Pregnancies", 'Age']

# %% [raw]
# Note : SelectKBest works on Statistical test to select features.
#        RFE works on model to select features

# %% [markdown]
# # Model 6 : SelectFromModel

# %%
_X_b
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1       0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2       0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3       0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4       0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# 5       0.294118  0.582915       0.606557       0.000000  0.000000  0.381520
# 6       0.176471  0.391960       0.409836       0.323232  0.104019  0.461997
# 7       0.588235  0.577889       0.000000       0.000000  0.000000  0.526080
# 8       0.117647  0.989950       0.573770       0.454545  0.641844  0.454545
# 9       0.470588  0.628141       0.786885       0.000000  0.000000  0.000000
# 10      0.235294  0.552764       0.754098       0.000000  0.000000  0.560358
# ...

# %%
sfm = SelectFromModel(LogisticRegression())

# %%
sfm
# Out:
# SelectFromModel(estimator=LogisticRegression(C=1.0, class_weight=None,
#                                              dual=False, fit_intercept=True,
#                                              intercept_scaling=1, l1_ratio=None,
#                                              max_iter=100, multi_class='warn',
#                                              n_jobs=None, penalty='l2',
#                                              random_state=None, solver='warn',
#                                              tol=0.0001, verbose=0,
#                                              warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
sfm.fit(_X_b,_y_b)
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# SelectFromModel(estimator=LogisticRegression(C=1.0, class_weight=None,
#                                              dual=False, fit_intercept=True,
#                                              intercept_scaling=1, l1_ratio=None,
#                                              max_iter=100, multi_class='warn',
#                                              n_jobs=None, penalty='l2',
#                                              random_state=None, solver='warn',
#                                              tol=0.0001, verbose=0,
#                                              warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
sfm.get_support()
# Out:
# array([False,  True, False, False, False,  True, False, False])

# %%
list(_X_b)
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
feature_6 = ['Glucose','BMI']
